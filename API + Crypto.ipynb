# %%
# API Proejct 
from requests import Request, Session
from requests.exceptions import ConnectionError, Timeout, TooManyRedirects
import json

url = 'https://pro-api.coinmarketcap.com/v1/cryptocurrency/listings/latest' 
parameters = {
  'start':'1',
  'limit':'15',
  'convert':'USD'
}
headers = {
  'Accepts': 'application/json',
  'X-CMC_PRO_API_KEY': '0ad53085-1cb2-4eb8-ad9e-3ffbd7e56509',
}

session = Session()
session.headers.update(headers)

try:
  response = session.get(url, params=parameters)
  data = json.loads(response.text)
  #print(data)
except (ConnectionError, Timeout, TooManyRedirects) as e:
  print(e)

# %%
type(data)
# Out:
# dict

# %%
import pandas as pd


#This allows you to see all the columns
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
#This normalizes the data in a dataframe

df = pd.json_normalize(data['data'])
df['timestamp'] = pd.to_datetime('now')
df
# Out:
#        id          name symbol          slug  num_market_pairs  \
# 0       1       Bitcoin    BTC       bitcoin             12036
# 1    1027      Ethereum    ETH      ethereum             10133
# 2     825   Tether USDt   USDT        tether            124233
# 3      52           XRP    XRP           xrp              1589
# 4    1839           BNB    BNB           bnb              2470
# 5    5426        Solana    SOL        solana               898
# 6    3408          USDC   USDC      usd-coin             27129
# 7    1958          TRON    TRX          tron              1164
# 8      74      Dogecoin   DOGE      dogecoin              1203
# 9    2010       Cardano    ADA       cardano              1505
# 10   3957  UNUS SED LEO    LEO  unus-sed-leo                59
# 11   1975     Chainlink   LINK     chainlink              1990
# 12   5805     Avalanche   AVAX     avalanche               906
# 13    512       Stellar    XLM       stellar               701
# 14  11419       Toncoin    TON       toncoin               719
#
#                   date_added  \
# 0   2010-07-13T00:00:00.000Z
# 1   2015-08-07T00:00:00.000Z
# 2   2015-02-25T00:00:00.000Z
# 3   2013-08-04T00:00:00.000Z
# 4   2017-07-25T00:00:00.000Z
# 5   2020-04-10T00:00:00.000Z
# 6   2018-10-08T00:00:00.000Z
# 7   2017-09-13T00:00:00.000Z
# 8   2013-12-15T00:00:00.000Z
# 9   2017-10-01T00:00:00.000Z
# 10  2019-05-21T00:00:00.000Z
# 11  2017-09-20T00:00:00.000Z
# 12  2020-07-13T00:00:00.000Z
# 13  2014-08-05T00:00:00.000Z
# 14  2021-08-26T13:40:22.000Z
#
#                                                  tags    max_supply  \
# 0   [mineable, pow, sha-256, store-of-value, state...  2.100000e+07
# 1   [pos, smart-contracts, ethereum-ecosystem, coi...           NaN
# 2   [stablecoin, asset-backed-stablecoin, usd-stab...           NaN
# 3   [medium-of-exchange, enterprise-solutions, xrp...  1.000000e+11
# 4   [marketplace, centralized-exchange, payments, ...           NaN
# 5   [pos, platform, solana-ecosystem, cms-holdings...           NaN
# 6   [medium-of-exchange, stablecoin, asset-backed-...           NaN
# 7   [media, payments, tron-ecosystem, layer-1, dwf...           NaN
# 8   [mineable, pow, scrypt, medium-of-exchange, me...           NaN
# 9   [dpos, pos, platform, research, smart-contract...  4.500000e+10
# 10  [marketplace, centralized-exchange, discount-t...           NaN
# 11  [platform, defi, oracles, smart-contracts, eth...           NaN
# 12  [defi, smart-contracts, three-arrows-capital-p...  7.157487e+08
# 13  [medium-of-exchange, enterprise-solutions, dec...  5.000181e+10
# 14  [pos, layer-1, ftx-bankruptcy-estate, dwf-labs...           NaN
#
#     circulating_supply  total_supply  infinite_supply  platform  cmc_rank  \
# 0         1.985196e+07  1.985196e+07            False       NaN         1
# 1         1.206954e+08  1.206954e+08             True       NaN         2
# 2         1.445736e+11  1.480590e+11             True       NaN         3
# 3         5.833814e+10  9.998625e+10            False       NaN         4
# 4         1.424703e+08  1.424703e+08            False       NaN         5
# 5         5.162823e+08  5.985794e+08             True       NaN         6
# 6         6.036615e+10  6.036615e+10            False       NaN         7
# 7         9.495604e+10  9.495604e+10             True       NaN         8
# 8         1.488718e+11  1.488718e+11             True       NaN         9
# 9         3.528711e+10  4.499493e+10            False       NaN        10
# 10        9.236831e+08  9.852395e+08            False       NaN        11
# 11        6.571000e+08  1.000000e+09            False       NaN        12
# 12        4.160259e+08  4.526954e+08            False       NaN        13
# 13        3.083316e+10  5.000179e+10            False       NaN        14
# 14        2.505984e+09  5.127332e+09             True       NaN        15
#
#    self_reported_circulating_supply self_reported_market_cap tvl_ratio  \
# 0                              None                     None      None
# 1                              None                     None      None
# 2                              None                     None      None
# 3                              None                     None      None
# 4                              None                     None      None
# 5                              None                     None      None
# 6                              None                     None      None
# 7                              None                     None      None
# 8                              None                     None      None
# 9                              None                     None      None
# 10                             None                     None      None
# 11                             None                     None      None
# 12                             None                     None      None
# 13                             None                     None      None
# 14                             None                     None      None
#
#                 last_updated  quote.USD.price  quote.USD.volume_24h  \
# 0   2025-04-16T05:04:00.000Z     83616.868064          2.691426e+10
# 1   2025-04-16T05:04:00.000Z      1588.848613          1.235685e+10
# 2   2025-04-16T05:03:00.000Z         0.999706          5.481529e+10
# 3   2025-04-16T05:04:00.000Z         2.082122          3.028167e+09
# 4   2025-04-16T05:04:00.000Z       583.085111          1.350680e+09
# 5   2025-04-16T05:04:00.000Z       126.065647          3.259149e+09
# 6   2025-04-16T05:03:00.000Z         0.999788          9.458315e+09
# 7   2025-04-16T05:03:00.000Z         0.252548          5.963537e+08
# 8   2025-04-16T05:04:00.000Z         0.155031          7.741108e+08
# 9   2025-04-16T05:04:00.000Z         0.609940          7.255559e+08
# 10  2025-04-16T05:04:00.000Z         9.365476          1.987833e+06
# 11  2025-04-16T05:04:00.000Z        12.320590          3.004788e+08
# 12  2025-04-16T05:04:00.000Z        18.850863          2.618084e+08
# 13  2025-04-16T05:04:00.000Z         0.235988          1.475216e+08
# 14  2025-04-16T05:04:00.000Z         2.887126          1.797933e+08
#
#     quote.USD.volume_change_24h  quote.USD.percent_change_1h  \
# 0                       -7.5861                    -0.050708
# 1                      -20.3089                    -0.087885
# 2                       -5.8328                    -0.016519
# 3                       -1.5781                     0.029821
# 4                       -0.8741                    -0.083733
# 5                      -15.5429                    -0.232673
# 6                      -10.4916                    -0.013215
# 7                       -0.3123                    -0.088028
# 8                      -14.1483                     0.026042
# 9                        8.4440                    -0.286975
# 10                     -28.9529                    -0.038652
# 11                       2.8297                    -0.533778
# 12                     -27.7571                    -0.353687
# 13                      -1.9048                     0.101385
# 14                      21.8059                    -0.640836
#
#     quote.USD.percent_change_24h  quote.USD.percent_change_7d  \
# 0                      -2.344219                     9.521456
# 1                      -3.252091                     9.961323
# 2                       0.010513                     0.046119
# 3                      -3.216083                    16.459439
# 4                      -0.985467                     6.431960
# 5                      -3.756593                    19.914428
# 6                       0.006296                    -0.015207
# 7                      -0.228095                    11.309986
# 8                      -3.504897                     9.040873
# 9                      -5.311897                     8.883323
# 10                     -0.719222                     2.193923
# 11                     -3.106786                    12.526727
# 12                     -6.373554                    15.210951
# 13                     -2.364172                     7.612660
# 14                     -1.811886                    -3.175262
#
#     quote.USD.percent_change_30d  quote.USD.percent_change_60d  \
# 0                       0.171444                    -14.284339
# 1                     -16.475440                    -41.612924
# 2                      -0.038574                     -0.036804
# 3                     -11.377399                    -25.485823
# 4                      -6.721879                    -11.358046
# 5                      -2.081974                    -36.148229
# 6                      -0.028719                     -0.015813
# 7                      18.525343                      8.536531
# 8                     -10.007803                    -44.285921
# 9                     -14.548917                    -24.615566
# 10                     -2.364345                     -4.573725
# 11                    -10.287348                    -36.873447
# 12                      1.394278                    -29.341192
# 13                    -13.428300                    -34.470128
# 14                    -18.981030                    -25.099266
#
#     quote.USD.percent_change_90d  quote.USD.market_cap  \
# 0                     -15.981246          1.659959e+12
# 1                     -52.899825          1.917668e+11
# 2                      -0.022009          1.445311e+11
# 3                     -32.191398          1.214671e+11
# 4                     -17.861798          8.307233e+10
# 5                     -37.495874          6.508546e+10
# 6                      -0.019586          6.035335e+10
# 7                       7.559588          2.398095e+10
# 8                     -58.879593          2.307976e+10
# 9                     -42.292214          2.152304e+10
# 10                     -2.701592          8.650732e+09
# 11                    -43.221325          8.095860e+09
# 12                    -51.941796          7.842447e+09
# 13                    -50.301906          7.276262e+09
# 14                    -47.513301          7.235092e+09
#
#     quote.USD.market_cap_dominance  quote.USD.fully_diluted_market_cap  \
# 0                          62.9583                        1.755954e+12
# 1                           7.2750                        1.917668e+11
# 2                           5.4830                        1.480155e+11
# 3                           4.6081                        2.082122e+11
# 4                           3.1507                        8.307233e+10
# 5                           2.4691                        7.546030e+10
# 6                           2.2896                        6.035335e+10
# 7                           0.9098                        2.398095e+10
# 8                           0.8754                        2.307976e+10
# 9                           0.8165                        2.744732e+10
# 10                          0.3282                        9.227237e+09
# 11                          0.3071                        1.232059e+10
# 12                          0.2975                        1.349248e+10
# 13                          0.2760                        1.179984e+10
# 14                          0.2745                        1.480325e+10
#
#    quote.USD.tvl    quote.USD.last_updated  platform.id platform.name  \
# 0           None  2025-04-16T05:04:00.000Z          NaN           NaN
# 1           None  2025-04-16T05:04:00.000Z          NaN           NaN
# 2           None  2025-04-16T05:03:00.000Z       1027.0      Ethereum
# 3           None  2025-04-16T05:04:00.000Z          NaN           NaN
# 4           None  2025-04-16T05:04:00.000Z          NaN           NaN
# 5           None  2025-04-16T05:04:00.000Z          NaN           NaN
# 6           None  2025-04-16T05:03:00.000Z       1027.0      Ethereum
# 7           None  2025-04-16T05:03:00.000Z          NaN           NaN
# 8           None  2025-04-16T05:04:00.000Z          NaN           NaN
# 9           None  2025-04-16T05:04:00.000Z          NaN           NaN
# 10          None  2025-04-16T05:04:00.000Z       1027.0      Ethereum
# 11          None  2025-04-16T05:04:00.000Z       1027.0      Ethereum
# 12          None  2025-04-16T05:04:00.000Z          NaN           NaN
# 13          None  2025-04-16T05:04:00.000Z          NaN           NaN
# 14          None  2025-04-16T05:04:00.000Z          NaN           NaN
#
#    platform.symbol platform.slug                      platform.token_address  \
# 0              NaN           NaN                                         NaN
# 1              NaN           NaN                                         NaN
# 2              ETH      ethereum  0xdac17f958d2ee523a2206206994597c13d831ec7
# 3              NaN           NaN                                         NaN
# 4              NaN           NaN                                         NaN
# 5              NaN           NaN                                         NaN
# 6              ETH      ethereum  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 7              NaN           NaN                                         NaN
# 8              NaN           NaN                                         NaN
# 9              NaN           NaN                                         NaN
# 10             ETH      ethereum  0x2af5d2ad76741191d15dfe7bf6ac92d4bd912ca3
# 11             ETH      ethereum  0x514910771af9ca656af840dff83e8264ecf986ca
# 12             NaN           NaN                                         NaN
# 13             NaN           NaN                                         NaN
# 14             NaN           NaN                                         NaN
#
#                     timestamp
# 0  2025-04-16 08:05:30.808441
# 1  2025-04-16 08:05:30.808441
# 2  2025-04-16 08:05:30.808441
# 3  2025-04-16 08:05:30.808441
# 4  2025-04-16 08:05:30.808441
# 5  2025-04-16 08:05:30.808441
# 6  2025-04-16 08:05:30.808441
# 7  2025-04-16 08:05:30.808441
# 8  2025-04-16 08:05:30.808441
# 9  2025-04-16 08:05:30.808441
# 10 2025-04-16 08:05:30.808441
# 11 2025-04-16 08:05:30.808441
# 12 2025-04-16 08:05:30.808441
# 13 2025-04-16 08:05:30.808441
# 14 2025-04-16 08:05:30.808441

# %%
def api_runner():
    global df
    url = 'https://pro-api.coinmarketcap.com/v1/cryptocurrency/listings/latest' 
    #Original Sandbox Environment: 'https://sandbox-api.coinmarketcap.com/v1/cryptocurrency/listings/latest'
    parameters = {
      'start':'1',
      'limit':'15',
      'convert':'USD'
    }
    headers = {
      'Accepts': 'application/json',
      'X-CMC_PRO_API_KEY': '0ad53085-1cb2-4eb8-ad9e-3ffbd7e56509',
    }

    session = Session()
    session.headers.update(headers)

    try:
      response = session.get(url, params=parameters)
      data = json.loads(response.text)
      #print(data)
    except (ConnectionError, Timeout, TooManyRedirects) as e:
      print(e)
    
    # Use this if you just want to keep it in a dataframe
    df2 = pd.json_normalize(data['data'])
    df2['Timestamp'] = pd.to_datetime('now')
    df = df.append(df2)

# %%
import os
from time import time 
from time import sleep

for i in range(333):
    api_runner()
    print('API Runner completed successfully')
    sleep(60)
exit()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/4n/qn0319rj6w9cwdg6hsfvsy3r0000gn/T/ipykernel_78106/3473938174.py in ?()
#       5 import os
# ----> 6 from time import time
#       7 from time import sleep
#       8
#       9 for i in range(333):
#
# /var/folders/4n/qn0319rj6w9cwdg6hsfvsy3r0000gn/T/ipykernel_78106/3754944509.py in ?()
#      24
#      25     # Use this if you just want to keep it in a dataframe
#      26     df2 = pd.json_normalize(data['data'])
#      27     df2['Timestamp'] = pd.to_datetime('now')
# ---> 28     df = df.append(df2)
#
# ~/Desktop/Python test/.venv/lib/python3.9/site-packages/pandas/core/generic.py in ?(self, name)
#    6295             and name not in self._accessors
#    6296             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'append'
