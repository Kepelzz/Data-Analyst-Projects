    },
    {
        "field_name": "EPS - Earnings Per Share",
        "popup_icon": "<div class='ajax-chart' data-tipped-options=\"ajax: {data: { t: 'NKE', s: 'eps-earnings-per-share-diluted', freq: 'A', statement: 'income-statement' }}\"><i style='font-size:18px; color:#337ab7;' class='fas fa-chart-bar'></i></span></div>",
        "2025-05-31": "2.16000",
        "2024-05-31": "3.73000",
        "2023-05-31": "3.23000",
        "2022-05-31": "3.75000",
        "2021-05-31": "3.56000",
        "2020-05-31": "1.60000",
        "2019-05-31": "2.49000",
        "2018-05-31": "1.17000",
        "2017-05-31": "2.51000",
        "2016-05-31": "2.16000",
        "2015-05-31": "1.85000",
        "2014-05-31": "1.49000",
        "2013-05-31": "1.35000",
        "2012-05-31": "1.17500",
        "2011-05-31": "1.10000",
        "2010-05-31": "0.96500",
        "2009-05-31": "0.75750"
    }
]

# %%
#Converting to DataFrame

df = pd.DataFrame(i_s).set_index("field_name").drop(columns=["popup_icon"]).transpose()
df.index.name = "year"
df = df.reset_index()
df["year"] = df["year"].str[:4]
df["EBIT"] = pd.to_numeric(df["EBIT"])
df = df.sort_values("year", ascending=True)

# %%
# Ploting barchart of ebit overtime

plt.figure(figsize=(12, 6))
plt.bar(df["year"], df["EBIT"])
plt.title("Nike EBIT Over Time")
plt.xlabel("Year")
plt.ylabel("EBIT (in millions USD)")
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--', alpha=0.5)
plt.tight_layout()
plt.show()

# %%
# Creating a chart that compares revenue to ebit and indicating EBIT's percentage of Revenue
df['year'] = df['year'].str[:4]
df['Revenue'] = pd.to_numeric(df['Revenue'])
df['EBIT'] = pd.to_numeric(df['EBIT'])
df['EBIT_pct'] = (df['EBIT']/df["Revenue"]) * 100

plt.figure(figsize=(14,7))
bar_width = 0.4
x = range(len(df))
plt.bar(x, df['Revenue'], width=bar_width, label='Revenue', color='lightblue')
plt.bar([i+bar_width for i in x], df["EBIT"], width=bar_width, label="EBIT", color='blue')
for i, pct in enumerate(df['EBIT_pct']):
    plt.text(i+bar_width, df['EBIT'].iloc[i]+500, f'{pct:.1f}%', ha='center', va='bottom', fontsize=8)
for i, val in enumerate(df["Revenue"]):
    plt.text(i, val + 500, f'{val:,.0f}', ha='center', va='bottom', fontsize=8, color='black')


plt.xticks([i + bar_width / 2 for i in x], df["year"], rotation=45)
plt.title("Nike Revenue vs EBIT (2009–2025) with EBIT % of Revenue")
plt.xlabel("Year")
plt.ylabel("USD (in millions)")
plt.legend()
plt.grid(axis='y', linestyle='--', alpha=0.6)
plt.tight_layout()
plt.show()

# %%
# Calculating and visualizing EBIT margin 
df["EBIT_margin"] = (df["EBIT"] / df["Revenue"]) * 100
median_margin = df["EBIT_margin"].median()

# Preparing barchart 
plt.figure(figsize=(14, 6))
bars = plt.bar(df["year"], df["EBIT_margin"], color="lightblue")

# Adding % labels above bars
for bar in bars:
    height = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, height + 0.3, f'{height:.1f}%', ha='center', va='bottom', fontsize=8)

#Median
plt.axhline(median_margin, color="blue", linestyle="--", linewidth=1.5, label=f"Median EBIT Margin: {median_margin:.1f}%")
plt.legend()

# Finalizing
plt.title("Nike EBIT Margin (%) — 2009 to 2025")
plt.xlabel("Year")
plt.ylabel("EBIT Margin (%)")
plt.xticks(rotation=45)
plt.grid(axis="y", linestyle="--", alpha=0.5)
plt.tight_layout()
plt.show()

# %%
# Observations 
# EBIT margins stay quite consistent over long periods of time which allows the company to stay profitable and be able to mitigate the crisis.
